# %% [markdown]
# # Computer Simulation Project Documentation
# ### Full Names : MohammadDanial Jahanbani, Erfan Sadrayie
# Student Number : 99105367, 99101835
# ___
# ## Libraries
# We used `Simpy` to simulate the 1-core system as a resource in our code and finally used `Pandas` to display the data for tasks.
# ## Implementation
# based on the system description we implemented the below algorithm. It consists of three main parts:
# </br>
# </br>
# <li>
#     <b>Creating jobs</b>: with time intervals $t_i$ exponentially distributed with rate $X$, jobs are created with a service time also exponentially distributed with rate $Y$ plus an exponentially distributed renege time with parameter $Z$. In addition, a priority is generated for this job which equals:$$pq\_priority = creation\_time \times c + priority$$ where $c$ indicates the imporance of creation time in proportion to the actual priority i.e 1 for high, 2 for normal and 3 for low.
# </li>
# </br>
# <li>
#     <b>Transferring jobs from layer 1 to Round Robin 1 </b>: In an iterative fashion, after each $T$ seconds the total number of tasks in second layer queues is checked and if it is less than $k$, the first $k$ elements are added to <i>Round Robin 1</i> priority queue.
# </li>
# </br>
# <li>
#     <b>Transferring jobs from a queue in layer 2 to the CPU core</b>: Based on our queue selection policy, we can operate two different queue selection for the core. if the policy is <i>Normal</i> then  at First the core will perform tasks from the <i>Round Robin 1</i> priority queue and if that is empty then it will accept tasks from <i>Round Robin 2</i> Priority queue and finally <i>FCFS</i> priority queue. However, if the policy is <i>Random</i> then the core will be provided with a task randomly selected from one of the three queues in layer 2.
# </li>
# </br>
# <li>
#     <b>Transferring jobs between queues of layer 2</b>: If a job in layer 2 has a service time higher than the quantum time of the queue it is currently in, then it should be moved to a queue with lower priority after it has been given service by the core equal to the quantum time of the queue it is currently in.
# </li>
# </br>
# <li>
#     <b>Checking for reneged jobs</b>: We iteratively check to see if any jobs have timed out and remove them from the queue they are currently in. If a job is being served by the core, it will not be affected by this.
# </li>
#
# ### Average Queue Lengths for different rates
# the below code does the job $X$, $Y$, $Z$:

# %%
from main import simulate
from numpy import mean

results = []
for x in range(5, 15, 2):
    for y in range(5, 15, 2):
        for z in range(0, 1000, 100):
            jobs_result, queue_result = simulate(x, y, z)
            print('entrance rate:', x, 'service rate:', y)
            print('average PQ length:', mean(queue_result['PQ length']))
            print('average R1 length:', mean(queue_result['R1 length']))
            print('average R2 length', mean(queue_result['R2 length']))
            print('average FCFS length', mean(queue_result['FCFS length']))
# Out:
# entrance rate: 5 service rate: 5
# average PQ length: 0.00575
# average R1 length: 0.0
# average R2 length 0.0
# average FCFS length 0.0
# entrance rate: 5 service rate: 5
# average PQ length: 0.79625
# average R1 length: 0.17825
# average R2 length 0.0255
# average FCFS length 0.0
# entrance rate: 5 service rate: 5
# average PQ length: 1.4505
# average R1 length: 0.25525
# average R2 length 0.05375
# average FCFS length 0.0
# entrance rate: 5 service rate: 5
# average PQ length: 2.30325
# average R1 length: 0.62
# average R2 length 0.16825
# average FCFS length 0.0
# entrance rate: 5 service rate: 5
# average PQ length: 2.2825
# average R1 length: 1.12425
# average R2 length 0.18425
# average FCFS length 0.0
# entrance rate: 5 service rate: 5
# average PQ length: 4.5225
# average R1 length: 1.0745
# average R2 length 0.1085
# average FCFS length 0.0
# entrance rate: 5 service rate: 5
# average PQ length: 4.01575
# average R1 length: 0.7105
# average R2 length 0.03625
# average FCFS length 0.0
# entrance rate: 5 service rate: 5
# average PQ length: 4.80975
# average R1 length: 0.86125
# average R2 length 0.00025
# average FCFS length 0.0
# entrance rate: 5 service rate: 5
# average PQ length: 5.93325
# average R1 length: 1.48375
# average R2 length 0.01225
# average FCFS length 0.0
# entrance rate: 5 service rate: 5
# average PQ length: 8.93175
# average R1 length: 2.56625
# average R2 length 0.196
# average FCFS length 0.0
# entrance rate: 5 service rate: 7
# average PQ length: 0.0055
# average R1 length: 0.0
# average R2 length 0.0
# average FCFS length 0.0
# entrance rate: 5 service rate: 7
# average PQ length: 0.66425
# average R1 length: 0.2455
# average R2 length 0.24975
# average FCFS length 0.0
# entrance rate: 5 service rate: 7
# average PQ length: 1.59975
# average R1 length: 0.371
# average R2 length 0.206
# average FCFS length 0.0
# entrance rate: 5 service rate: 7
# average PQ length: 2.7045
# average R1 length: 1.51625
# average R2 length 0.2555
# average FCFS length 0.0
# entrance rate: 5 service rate: 7
# average PQ length: 2.04025
# average R1 length: 0.78025
# average R2 length 0.15025
# average FCFS length 0.0
# entrance rate: 5 service rate: 7
# average PQ length: 2.7135
# average R1 length: 1.124
# average R2 length 0.44275
# average FCFS length 0.0
# entrance rate: 5 service rate: 7
# average PQ length: 3.89875
# average R1 length: 2.448
# average R2 length 0.8835
# average FCFS length 0.0
# entrance rate: 5 service rate: 7
# average PQ length: 5.22
# average R1 length: 4.5205
# average R2 length 0.0505
# average FCFS length 0.0
# entrance rate: 5 service rate: 7
# average PQ length: 7.04675
# average R1 length: 1.51975
# average R2 length 1.0765
# average FCFS length 0.0
# entrance rate: 5 service rate: 7
# average PQ length: 6.2435
# average R1 length: 1.5105
# average R2 length 0.074
# average FCFS length 0.0
# entrance rate: 5 service rate: 9
# average PQ length: 0.0065
# average R1 length: 0.0
# average R2 length 0.0
# average FCFS length 0.0
# entrance rate: 5 service rate: 9
# average PQ length: 0.74975
# average R1 length: 0.29775
# average R2 length 0.04575
# average FCFS length 0.0
# entrance rate: 5 service rate: 9
# average PQ length: 1.18925
# average R1 length: 0.59625
# average R2 length 0.5435
# average FCFS length 0.0
# entrance rate: 5 service rate: 9
# average PQ length: 2.09575
# average R1 length: 2.02325
# average R2 length 0.47975
# average FCFS length 0.0
# entrance rate: 5 service rate: 9
# average PQ length: 2.416
# average R1 length: 0.619
# average R2 length 0.071
# average FCFS length 0.0
# entrance rate: 5 service rate: 9
# average PQ length: 4.04425
# average R1 length: 2.784
# average R2 length 1.34575
# average FCFS length 0.0
# entrance rate: 5 service rate: 9
# average PQ length: 5.22325
# average R1 length: 5.4965
# average R2 length 1.24775
# average FCFS length 0.0
# entrance rate: 5 service rate: 9
# average PQ length: 4.14325
# average R1 length: 2.2295
# average R2 length 0.995
# average FCFS length 0.0
# entrance rate: 5 service rate: 9
# average PQ length: 7.011
# average R1 length: 2.284
# average R2 length 0.546
# average FCFS length 0.0
# entrance rate: 5 service rate: 9
# average PQ length: 7.63875
# average R1 length: 1.6775
# average R2 length 0.079
# average FCFS length 0.0
# entrance rate: 5 service rate: 11
# average PQ length: 0.0065
# average R1 length: 0.0
# average R2 length 0.0
# average FCFS length 0.0
# entrance rate: 5 service rate: 11
# average PQ length: 0.8495
# average R1 length: 0.27175
# average R2 length 0.4245
# average FCFS length 0.00025
# entrance rate: 5 service rate: 11
# average PQ length: 1.3445
# average R1 length: 0.7045
# average R2 length 0.56
# average FCFS length 0.0
# entrance rate: 5 service rate: 11
# average PQ length: 3.121
# average R1 length: 5.79175
# average R2 length 1.22275
# average FCFS length 0.0
# entrance rate: 5 service rate: 11
# average PQ length: 3.3405
# average R1 length: 2.51075
# average R2 length 1.12125
# average FCFS length 0.0
# entrance rate: 5 service rate: 11
# average PQ length: 3.2935
# average R1 length: 1.57525
# average R2 length 0.783
# average FCFS length 0.0
# entrance rate: 5 service rate: 11
# average PQ length: 3.939
# average R1 length: 2.7115
# average R2 length 0.883
# average FCFS length 0.0
# entrance rate: 5 service rate: 11
# average PQ length: 4.2285
# average R1 length: 5.22675
# average R2 length 0.5685
# average FCFS length 0.00025
# entrance rate: 5 service rate: 11
# average PQ length: 5.6365
# average R1 length: 3.9815
# average R2 length 1.0435
# average FCFS length 0.0
# entrance rate: 5 service rate: 11
# average PQ length: 6.63325
# average R1 length: 3.36675
# average R2 length 0.95525
# average FCFS length 0.0
# entrance rate: 5 service rate: 13
# average PQ length: 0.00625
# average R1 length: 0.0
# average R2 length 0.0
# average FCFS length 0.0
# entrance rate: 5 service rate: 13
# average PQ length: 0.8845
# average R1 length: 0.4085
# average R2 length 0.13425
# average FCFS length 0.0
# entrance rate: 5 service rate: 13
# average PQ length: 1.313
# average R1 length: 1.11475
# average R2 length 1.135
# average FCFS length 0.00025
# entrance rate: 5 service rate: 13
# average PQ length: 2.1525
# average R1 length: 1.371
# average R2 length 0.7355
# average FCFS length 0.0
# entrance rate: 5 service rate: 13
# average PQ length: 2.4605
# average R1 length: 2.355
# average R2 length 0.374
# average FCFS length 0.00025
# entrance rate: 5 service rate: 13
# average PQ length: 3.66725
# average R1 length: 2.8595
# average R2 length 0.757
# average FCFS length 0.0
# entrance rate: 5 service rate: 13
# average PQ length: 5.371
# average R1 length: 9.0955
# average R2 length 2.489
# average FCFS length 0.0
# entrance rate: 5 service rate: 13
# average PQ length: 6.581
# average R1 length: 11.65425
# average R2 length 0.87125
# average FCFS length 0.0005
# entrance rate: 5 service rate: 13
# average PQ length: 6.0685
# average R1 length: 1.903
# average R2 length 0.4655
# average FCFS length 0.0
# entrance rate: 5 service rate: 13
# average PQ length: 6.8195
# average R1 length: 4.479
# average R2 length 2.13
# average FCFS length 0.0
# entrance rate: 7 service rate: 5
# average PQ length: 0.006
# average R1 length: 0.0
# average R2 length 0.0
# average FCFS length 0.0
# entrance rate: 7 service rate: 5
# average PQ length: 0.6085
# average R1 length: 0.09575
# average R2 length 0.0115
# average FCFS length 0.0
# entrance rate: 7 service rate: 5
# average PQ length: 1.4485
# average R1 length: 0.414
# average R2 length 0.01825
# average FCFS length 0.0
# entrance rate: 7 service rate: 5
# average PQ length: 2.4175
# average R1 length: 0.79525
# average R2 length 0.048
# average FCFS length 0.0
# entrance rate: 7 service rate: 5
# average PQ length: 2.16825
# average R1 length: 0.36625
# average R2 length 0.00925
# average FCFS length 0.0
# entrance rate: 7 service rate: 5
# average PQ length: 3.24925
# average R1 length: 0.958
# average R2 length 0.02575
# average FCFS length 0.0
# entrance rate: 7 service rate: 5
# average PQ length: 3.22325
# average R1 length: 3.85625
# average R2 length 0.057
# average FCFS length 0.0
# entrance rate: 7 service rate: 5
# average PQ length: 5.9375
# average R1 length: 0.7775
# average R2 length 0.01425
# average FCFS length 0.0
# entrance rate: 7 service rate: 5
# average PQ length: 6.1515
# average R1 length: 1.178
# average R2 length 0.0655
# average FCFS length 0.0
# entrance rate: 7 service rate: 5
# average PQ length: 9.01225
# average R1 length: 1.61925
# average R2 length 0.0105
# average FCFS length 0.0
# entrance rate: 7 service rate: 7
# average PQ length: 0.00625
# average R1 length: 0.0
# average R2 length 0.0
# average FCFS length 0.0
# entrance rate: 7 service rate: 7
# average PQ length: 0.533
# average R1 length: 0.1315
# average R2 length 0.00825
# average FCFS length 0.0
# entrance rate: 7 service rate: 7
# average PQ length: 1.35625
# average R1 length: 0.46525
# average R2 length 0.20825
# average FCFS length 0.0
# entrance rate: 7 service rate: 7
# average PQ length: 2.0765
# average R1 length: 0.89525
# average R2 length 0.13125
# average FCFS length 0.0
# entrance rate: 7 service rate: 7
# average PQ length: 2.52325
# average R1 length: 0.579
# average R2 length 0.0185
# average FCFS length 0.0
# entrance rate: 7 service rate: 7
# average PQ length: 3.403
# average R1 length: 1.05975
# average R2 length 0.04575
# average FCFS length 0.0
# entrance rate: 7 service rate: 7
# average PQ length: 5.3395
# average R1 length: 1.26175
# average R2 length 0.48375
# average FCFS length 0.0
# entrance rate: 7 service rate: 7
# average PQ length: 6.471
# average R1 length: 1.504
# average R2 length 0.0175
# average FCFS length 0.0
# entrance rate: 7 service rate: 7
# average PQ length: 5.16
# average R1 length: 0.93175
# average R2 length 0.2535
# average FCFS length 0.0
# entrance rate: 7 service rate: 7
# average PQ length: 8.313
# average R1 length: 2.47575
# average R2 length 0.33075
# average FCFS length 0.0
# entrance rate: 7 service rate: 9
# average PQ length: 0.006
# average R1 length: 0.0
# average R2 length 0.0
# average FCFS length 0.0
# entrance rate: 7 service rate: 9
# average PQ length: 0.837
# average R1 length: 0.38575
# average R2 length 0.13625
# average FCFS length 0.0
# entrance rate: 7 service rate: 9
# average PQ length: 1.3945
# average R1 length: 1.11125
# average R2 length 0.33425
# average FCFS length 0.0
# entrance rate: 7 service rate: 9
# average PQ length: 2.11925
# average R1 length: 0.78125
# average R2 length 0.635
# average FCFS length 0.0
# entrance rate: 7 service rate: 9
# average PQ length: 1.77675
# average R1 length: 0.54825
# average R2 length 0.81725
# average FCFS length 0.0
# entrance rate: 7 service rate: 9
# average PQ length: 3.1335
# average R1 length: 0.97925
# average R2 length 0.076
# average FCFS length 0.0
# entrance rate: 7 service rate: 9
# average PQ length: 6.19825
# average R1 length: 4.852
# average R2 length 0.35875
# average FCFS length 0.0
# entrance rate: 7 service rate: 9
# average PQ length: 5.12175
# average R1 length: 1.12875
# average R2 length 0.3315
# average FCFS length 0.0
# entrance rate: 7 service rate: 9
# average PQ length: 6.36225
# average R1 length: 6.39675
# average R2 length 1.823
# average FCFS length 0.0
# entrance rate: 7 service rate: 9
# average PQ length: 6.38625
# average R1 length: 3.20725
# average R2 length 0.826
# average FCFS length 0.0
# entrance rate: 7 service rate: 11
# average PQ length: 0.006
# average R1 length: 0.0
# average R2 length 0.0
# average FCFS length 0.0
# entrance rate: 7 service rate: 11
# average PQ length: 0.60725
# average R1 length: 0.2495
# average R2 length 0.01225
# average FCFS length 0.0
# entrance rate: 7 service rate: 11
# average PQ length: 1.55375
# average R1 length: 1.84375
# average R2 length 0.908
# average FCFS length 0.00025
# entrance rate: 7 service rate: 11
# average PQ length: 2.403
# average R1 length: 2.3055
# average R2 length 1.28875
# average FCFS length 0.0
# entrance rate: 7 service rate: 11
# average PQ length: 3.01225
# average R1 length: 0.9755
# average R2 length 0.54975
# average FCFS length 0.0
# entrance rate: 7 service rate: 11
# average PQ length: 3.7755
# average R1 length: 8.03775
# average R2 length 1.2635
# average FCFS length 0.0005
# entrance rate: 7 service rate: 11
# average PQ length: 4.86425
# average R1 length: 4.025
# average R2 length 0.18325
# average FCFS length 0.0
# entrance rate: 7 service rate: 11
# average PQ length: 4.51325
# average R1 length: 2.0095
# average R2 length 0.7325
# average FCFS length 0.0
# entrance rate: 7 service rate: 11
# average PQ length: 6.892
# average R1 length: 2.0895
# average R2 length 1.20175
# average FCFS length 0.0
# entrance rate: 7 service rate: 11
# average PQ length: 5.52675
# average R1 length: 4.0945
# average R2 length 0.2625
# average FCFS length 0.00025
# entrance rate: 7 service rate: 13
# average PQ length: 0.00625
# average R1 length: 0.0
# average R2 length 0.0
# average FCFS length 0.0
# entrance rate: 7 service rate: 13
# average PQ length: 0.75025
# average R1 length: 0.3795
# average R2 length 0.33925
# average FCFS length 0.0
# entrance rate: 7 service rate: 13
# average PQ length: 1.94425
# average R1 length: 1.3615
# average R2 length 0.398
# average FCFS length 0.0
# entrance rate: 7 service rate: 13
# average PQ length: 1.8075
# average R1 length: 1.6005
# average R2 length 0.46525
# average FCFS length 0.0
# entrance rate: 7 service rate: 13
# average PQ length: 3.018
# average R1 length: 1.806
# average R2 length 1.25025
# average FCFS length 0.0
# entrance rate: 7 service rate: 13
# average PQ length: 3.21575
# average R1 length: 1.14725
# average R2 length 0.771
# average FCFS length 0.0
# entrance rate: 7 service rate: 13
# average PQ length: 4.40125
# average R1 length: 2.67675
# average R2 length 0.9215
# average FCFS length 0.0
# entrance rate: 7 service rate: 13
# average PQ length: 6.4925
# average R1 length: 8.796
# average R2 length 2.614
# average FCFS length 0.0
# entrance rate: 7 service rate: 13
# average PQ length: 5.565
# average R1 length: 2.906
# average R2 length 0.578
# average FCFS length 0.00025
# entrance rate: 7 service rate: 13
# average PQ length: 10.28975
# average R1 length: 4.49125
# average R2 length 4.454
# average FCFS length 0.00025
# entrance rate: 9 service rate: 5
# average PQ length: 0.00675
# average R1 length: 0.0
# average R2 length 0.0
# average FCFS length 0.0
# entrance rate: 9 service rate: 5
# average PQ length: 0.7305
# average R1 length: 0.25475
# average R2 length 0.045
# average FCFS length 0.0
# entrance rate: 9 service rate: 5
# average PQ length: 1.27275
# average R1 length: 0.368
# average R2 length 0.01425
# average FCFS length 0.0
# entrance rate: 9 service rate: 5
# average PQ length: 2.356
# average R1 length: 0.76825
# average R2 length 0.0115
# average FCFS length 0.0
# entrance rate: 9 service rate: 5
# average PQ length: 3.18575
# average R1 length: 0.80575
# average R2 length 0.49
# average FCFS length 0.0
# entrance rate: 9 service rate: 5
# average PQ length: 3.72675
# average R1 length: 0.591
# average R2 length 0.00925
# average FCFS length 0.0
# entrance rate: 9 service rate: 5
# average PQ length: 4.85025
# average R1 length: 0.8985
# average R2 length 0.01275
# average FCFS length 0.0
# entrance rate: 9 service rate: 5
# average PQ length: 5.1775
# average R1 length: 80.48225
# average R2 length 0.0
# average FCFS length 0.0
# entrance rate: 9 service rate: 5
# average PQ length: 4.92775
# average R1 length: 1.75875
# average R2 length 0.02425
# average FCFS length 0.0
# entrance rate: 9 service rate: 5
# average PQ length: 9.5645
# average R1 length: 1.8475
# average R2 length 0.003
# average FCFS length 0.0
# entrance rate: 9 service rate: 7
# average PQ length: 0.007
# average R1 length: 0.0
# average R2 length 0.0
# average FCFS length 0.0
# entrance rate: 9 service rate: 7
# average PQ length: 0.76
# average R1 length: 0.249
# average R2 length 0.09775
# average FCFS length 0.0
# entrance rate: 9 service rate: 7
# average PQ length: 1.348
# average R1 length: 1.0505
# average R2 length 0.33175
# average FCFS length 0.0
# entrance rate: 9 service rate: 7
# average PQ length: 2.0135
# average R1 length: 0.784
# average R2 length 0.422
# average FCFS length 0.00025
# entrance rate: 9 service rate: 7
# average PQ length: 2.8535
# average R1 length: 1.75375
# average R2 length 0.19175
# average FCFS length 0.0
# entrance rate: 9 service rate: 7
# average PQ length: 5.18025
# average R1 length: 4.86425
# average R2 length 0.66675
# average FCFS length 0.0
# entrance rate: 9 service rate: 7
# average PQ length: 4.34625
# average R1 length: 3.194
# average R2 length 0.48125
# average FCFS length 0.0
# entrance rate: 9 service rate: 7
# average PQ length: 6.95475
# average R1 length: 1.66525
# average R2 length 0.759
# average FCFS length 0.0
# entrance rate: 9 service rate: 7
# average PQ length: 5.33675
# average R1 length: 1.27525
# average R2 length 0.104
# average FCFS length 0.0
# entrance rate: 9 service rate: 7
# average PQ length: 6.31725
# average R1 length: 2.767
# average R2 length 0.10275
# average FCFS length 0.0
# entrance rate: 9 service rate: 9
# average PQ length: 0.007
# average R1 length: 0.0
# average R2 length 0.0
# average FCFS length 0.0
# entrance rate: 9 service rate: 9
# average PQ length: 0.81425
# average R1 length: 0.396
# average R2 length 0.08775
# average FCFS length 0.0
# entrance rate: 9 service rate: 9
# average PQ length: 1.77025
# average R1 length: 1.8745
# average R2 length 0.14025
# average FCFS length 0.0
# entrance rate: 9 service rate: 9
# average PQ length: 2.01375
# average R1 length: 0.6695
# average R2 length 0.32
# average FCFS length 0.0
# entrance rate: 9 service rate: 9
# average PQ length: 3.7035
# average R1 length: 2.66275
# average R2 length 0.5415
# average FCFS length 0.0
# entrance rate: 9 service rate: 9
# average PQ length: 4.21725
# average R1 length: 1.37825
# average R2 length 0.1095
# average FCFS length 0.0
# entrance rate: 9 service rate: 9
# average PQ length: 4.55775
# average R1 length: 3.37825
# average R2 length 0.4995
# average FCFS length 0.00025
# entrance rate: 9 service rate: 9
# average PQ length: 6.307
# average R1 length: 1.638
# average R2 length 0.13475
# average FCFS length 0.0
# entrance rate: 9 service rate: 9
# average PQ length: 6.47475
# average R1 length: 2.665
# average R2 length 0.2575
# average FCFS length 0.0
# entrance rate: 9 service rate: 9
# average PQ length: 6.375
# average R1 length: 4.06975
# average R2 length 1.10225
# average FCFS length 0.0
# entrance rate: 9 service rate: 11
# average PQ length: 0.0065
# average R1 length: 0.0
# average R2 length 0.0
# average FCFS length 0.0
# entrance rate: 9 service rate: 11
# average PQ length: 0.8025
# average R1 length: 0.363
# average R2 length 0.05325
# average FCFS length 0.0
# entrance rate: 9 service rate: 11
# average PQ length: 1.508
# average R1 length: 0.458
# average R2 length 0.28425
# average FCFS length 0.0
# entrance rate: 9 service rate: 11
# average PQ length: 2.098
# average R1 length: 1.85075
# average R2 length 0.5645
# average FCFS length 0.0
# entrance rate: 9 service rate: 11
# average PQ length: 2.9215
# average R1 length: 1.112
# average R2 length 0.47225
# average FCFS length 0.0
# entrance rate: 9 service rate: 11
# average PQ length: 4.31525
# average R1 length: 1.35
# average R2 length 0.11675
# average FCFS length 0.0
# entrance rate: 9 service rate: 11
# average PQ length: 4.627
# average R1 length: 5.00175
# average R2 length 1.3045
# average FCFS length 0.0
# entrance rate: 9 service rate: 11
# average PQ length: 5.42
# average R1 length: 3.5575
# average R2 length 1.4165
# average FCFS length 0.0
# entrance rate: 9 service rate: 11
# average PQ length: 6.56825
# average R1 length: 20.1895
# average R2 length 0.56675
# average FCFS length 0.0
# entrance rate: 9 service rate: 11
# average PQ length: 6.0005
# average R1 length: 3.0875
# average R2 length 0.372
# average FCFS length 0.0
# entrance rate: 9 service rate: 13
# average PQ length: 0.00575
# average R1 length: 0.00025
# average R2 length 0.0
# average FCFS length 0.0
# entrance rate: 9 service rate: 13
# average PQ length: 0.995
# average R1 length: 0.529
# average R2 length 0.5865
# average FCFS length 0.0
# entrance rate: 9 service rate: 13
# average PQ length: 1.32175
# average R1 length: 1.0585
# average R2 length 0.40925
# average FCFS length 0.0
# entrance rate: 9 service rate: 13
# average PQ length: 2.44475
# average R1 length: 0.8135
# average R2 length 0.52675
# average FCFS length 0.0
# entrance rate: 9 service rate: 13
# average PQ length: 2.36275
# average R1 length: 1.243
# average R2 length 0.30825
# average FCFS length 0.0
# entrance rate: 9 service rate: 13
# average PQ length: 3.46675
# average R1 length: 1.64875
# average R2 length 1.083
# average FCFS length 0.0
# entrance rate: 9 service rate: 13
# average PQ length: 4.8615
# average R1 length: 9.6755
# average R2 length 1.96075
# average FCFS length 0.0
# entrance rate: 9 service rate: 13
# average PQ length: 4.49
# average R1 length: 1.813
# average R2 length 0.236
# average FCFS length 0.0
# entrance rate: 9 service rate: 13
# average PQ length: 5.4475
# average R1 length: 2.22875
# average R2 length 0.32525
# average FCFS length 0.0
# entrance rate: 9 service rate: 13
# average PQ length: 7.641
# average R1 length: 9.17075
# average R2 length 0.94075
# average FCFS length 0.0
# entrance rate: 11 service rate: 5
# average PQ length: 0.0065
# average R1 length: 0.0
# average R2 length 0.0
# average FCFS length 0.0
# entrance rate: 11 service rate: 5
# average PQ length: 0.66275
# average R1 length: 0.1575
# average R2 length 0.02975
# average FCFS length 0.00025
# entrance rate: 11 service rate: 5
# average PQ length: 1.6055
# average R1 length: 0.32725
# average R2 length 0.012
# average FCFS length 0.0
# entrance rate: 11 service rate: 5
# average PQ length: 2.06275
# average R1 length: 0.49575
# average R2 length 0.01875
# average FCFS length 0.0
# entrance rate: 11 service rate: 5
# average PQ length: 3.22025
# average R1 length: 0.8425
# average R2 length 0.01175
# average FCFS length 0.0
# entrance rate: 11 service rate: 5
# average PQ length: 3.08525
# average R1 length: 0.44075
# average R2 length 0.007
# average FCFS length 0.0
# entrance rate: 11 service rate: 5
# average PQ length: 4.57225
# average R1 length: 0.5785
# average R2 length 0.007
# average FCFS length 0.0
# entrance rate: 11 service rate: 5
# average PQ length: 4.374
# average R1 length: 2.0455
# average R2 length 0.07125
# average FCFS length 0.0
# entrance rate: 11 service rate: 5
# average PQ length: 5.9945
# average R1 length: 1.886
# average R2 length 0.03675
# average FCFS length 0.0
# entrance rate: 11 service rate: 5
# average PQ length: 7.4575
# average R1 length: 1.64925
# average R2 length 0.0135
# average FCFS length 0.0
# entrance rate: 11 service rate: 7
# average PQ length: 0.0065
# average R1 length: 0.0
# average R2 length 0.0
# average FCFS length 0.0
# entrance rate: 11 service rate: 7
# average PQ length: 0.51025
# average R1 length: 1.17125
# average R2 length 0.0
# average FCFS length 0.0
# entrance rate: 11 service rate: 7
# average PQ length: 1.51475
# average R1 length: 1.07875
# average R2 length 0.091
# average FCFS length 0.0
# entrance rate: 11 service rate: 7
# average PQ length: 2.2705
# average R1 length: 2.0315
# average R2 length 0.12375
# average FCFS length 0.0
# entrance rate: 11 service rate: 7
# average PQ length: 2.4185
# average R1 length: 0.8745
# average R2 length 0.027
# average FCFS length 0.0
# entrance rate: 11 service rate: 7
# average PQ length: 3.7345
# average R1 length: 0.78425
# average R2 length 0.0515
# average FCFS length 0.00025
# entrance rate: 11 service rate: 7
# average PQ length: 3.32775
# average R1 length: 40.06775
# average R2 length 0.0
# average FCFS length 0.0
# entrance rate: 11 service rate: 7
# average PQ length: 6.2035
# average R1 length: 113.4785
# average R2 length 0.0
# average FCFS length 0.0
# entrance rate: 11 service rate: 7
# average PQ length: 4.35625
# average R1 length: 2.07475
# average R2 length 0.5265
# average FCFS length 0.0
# entrance rate: 11 service rate: 7
# average PQ length: 7.53625
# average R1 length: 2.41925
# average R2 length 0.28775
# average FCFS length 0.0
# entrance rate: 11 service rate: 9
# average PQ length: 0.0065
# average R1 length: 0.0
# average R2 length 0.0
# average FCFS length 0.0
# entrance rate: 11 service rate: 9
# average PQ length: 0.56
# average R1 length: 0.11425
# average R2 length 0.0245
# average FCFS length 0.0
# entrance rate: 11 service rate: 9
# average PQ length: 1.326
# average R1 length: 0.52125
# average R2 length 0.1775
# average FCFS length 0.0
# entrance rate: 11 service rate: 9
# average PQ length: 1.56
# average R1 length: 0.64375
# average R2 length 0.11325
# average FCFS length 0.0
# entrance rate: 11 service rate: 9
# average PQ length: 3.39125
# average R1 length: 1.8155
# average R2 length 0.2585
# average FCFS length 0.00025
# entrance rate: 11 service rate: 9
# average PQ length: 3.7265
# average R1 length: 3.326
# average R2 length 0.016
# average FCFS length 0.0
# entrance rate: 11 service rate: 9
# average PQ length: 3.25075
# average R1 length: 0.94375
# average R2 length 0.17275
# average FCFS length 0.0
# entrance rate: 11 service rate: 9
# average PQ length: 6.5265
# average R1 length: 2.941
# average R2 length 0.27175
# average FCFS length 0.0
# entrance rate: 11 service rate: 9
# average PQ length: 5.99875
# average R1 length: 1.42
# average R2 length 0.1495
# average FCFS length 0.0
# entrance rate: 11 service rate: 9
# average PQ length: 6.062
# average R1 length: 2.887
# average R2 length 2.61725
# average FCFS length 0.0
# entrance rate: 11 service rate: 11
# average PQ length: 0.00675
# average R1 length: 0.0
# average R2 length 0.0
# average FCFS length 0.0
# entrance rate: 11 service rate: 11
# average PQ length: 0.85875
# average R1 length: 0.28575
# average R2 length 0.05425
# average FCFS length 0.0
# entrance rate: 11 service rate: 11
# average PQ length: 1.4405
# average R1 length: 1.3565
# average R2 length 0.675
# average FCFS length 0.0
# entrance rate: 11 service rate: 11
# average PQ length: 2.743
# average R1 length: 0.70025
# average R2 length 0.2825
# average FCFS length 0.0
# entrance rate: 11 service rate: 11
# average PQ length: 2.63375
# average R1 length: 0.74825
# average R2 length 0.09625
# average FCFS length 0.0
# entrance rate: 11 service rate: 11
# average PQ length: 3.14025
# average R1 length: 1.08625
# average R2 length 0.1905
# average FCFS length 0.0
# entrance rate: 11 service rate: 11
# average PQ length: 4.8885
# average R1 length: 2.63175
# average R2 length 2.56025
# average FCFS length 0.0
# entrance rate: 11 service rate: 11
# average PQ length: 3.98275
# average R1 length: 4.00375
# average R2 length 1.61025
# average FCFS length 0.0
# entrance rate: 11 service rate: 11
# average PQ length: 4.446
# average R1 length: 4.91375
# average R2 length 0.7775
# average FCFS length 0.0
# entrance rate: 11 service rate: 11
# average PQ length: 4.95225
# average R1 length: 89.7775
# average R2 length 0.0
# average FCFS length 0.0
# entrance rate: 11 service rate: 13
# average PQ length: 0.007
# average R1 length: 0.0
# average R2 length 0.0
# average FCFS length 0.0
# entrance rate: 11 service rate: 13
# average PQ length: 0.734
# average R1 length: 0.3595
# average R2 length 0.2235
# average FCFS length 0.0
# entrance rate: 11 service rate: 13
# average PQ length: 1.5775
# average R1 length: 1.3255
# average R2 length 0.5665
# average FCFS length 0.00025
# entrance rate: 11 service rate: 13
# average PQ length: 1.9205
# average R1 length: 0.83675
# average R2 length 1.08225
# average FCFS length 0.0
# entrance rate: 11 service rate: 13
# average PQ length: 3.01
# average R1 length: 1.91275
# average R2 length 1.553
# average FCFS length 0.0
# entrance rate: 11 service rate: 13
# average PQ length: 4.17575
# average R1 length: 1.661
# average R2 length 0.75675
# average FCFS length 0.0
# entrance rate: 11 service rate: 13
# average PQ length: 6.35225
# average R1 length: 16.019
# average R2 length 1.94325
# average FCFS length 0.0
# entrance rate: 11 service rate: 13
# average PQ length: 3.728
# average R1 length: 1.30275
# average R2 length 0.115
# average FCFS length 0.00025
# entrance rate: 11 service rate: 13
# average PQ length: 6.6895
# average R1 length: 5.61
# average R2 length 0.913
# average FCFS length 0.0
# entrance rate: 11 service rate: 13
# average PQ length: 5.768
# average R1 length: 1.783
# average R2 length 0.54625
# average FCFS length 0.0
# entrance rate: 13 service rate: 5
# average PQ length: 0.00675
# average R1 length: 0.0
# average R2 length 0.0
# average FCFS length 0.0
# entrance rate: 13 service rate: 5
# average PQ length: 0.777
# average R1 length: 0.1865
# average R2 length 0.01
# average FCFS length 0.0
# entrance rate: 13 service rate: 5
# average PQ length: 1.81325
# average R1 length: 0.3945
# average R2 length 0.0105
# average FCFS length 0.0
# entrance rate: 13 service rate: 5
# average PQ length: 2.10725
# average R1 length: 0.34325
# average R2 length 0.00825
# average FCFS length 0.0
# entrance rate: 13 service rate: 5
# average PQ length: 2.571
# average R1 length: 0.59075
# average R2 length 0.00725
# average FCFS length 0.0
# entrance rate: 13 service rate: 5
# average PQ length: 3.159
# average R1 length: 1.24225
# average R2 length 0.1225
# average FCFS length 0.0
# entrance rate: 13 service rate: 5
# average PQ length: 4.7075
# average R1 length: 0.846
# average R2 length 0.01075
# average FCFS length 0.0
# entrance rate: 13 service rate: 5
# average PQ length: 4.5345
# average R1 length: 1.2745
# average R2 length 0.15125
# average FCFS length 0.0
# entrance rate: 13 service rate: 5
# average PQ length: 8.376
# average R1 length: 2.54275
# average R2 length 0.41
# average FCFS length 0.0
# entrance rate: 13 service rate: 5
# average PQ length: 4.89775
# average R1 length: 0.8625
# average R2 length 0.02225
# average FCFS length 0.0
# entrance rate: 13 service rate: 7
# average PQ length: 0.0075
# average R1 length: 0.0
# average R2 length 0.0
# average FCFS length 0.0
# entrance rate: 13 service rate: 7
# average PQ length: 0.531
# average R1 length: 0.11475
# average R2 length 0.06275
# average FCFS length 0.0
# entrance rate: 13 service rate: 7
# average PQ length: 1.04125
# average R1 length: 0.36775
# average R2 length 0.0215
# average FCFS length 0.0
# entrance rate: 13 service rate: 7
# average PQ length: 1.975
# average R1 length: 0.573
# average R2 length 0.05875
# average FCFS length 0.0
# entrance rate: 13 service rate: 7
# average PQ length: 2.65275
# average R1 length: 0.64375
# average R2 length 0.0205
# average FCFS length 0.0
# entrance rate: 13 service rate: 7
# average PQ length: 3.913
# average R1 length: 1.639
# average R2 length 0.68825
# average FCFS length 0.0
# entrance rate: 13 service rate: 7
# average PQ length: 5.2645
# average R1 length: 1.078
# average R2 length 0.036
# average FCFS length 0.0
# entrance rate: 13 service rate: 7
# average PQ length: 5.29775
# average R1 length: 1.00325
# average R2 length 0.0285
# average FCFS length 0.0
# entrance rate: 13 service rate: 7
# average PQ length: 6.78925
# average R1 length: 1.31725
# average R2 length 0.0665
# average FCFS length 0.0
# entrance rate: 13 service rate: 7
# average PQ length: 7.269
# average R1 length: 1.67025
# average R2 length 0.7205
# average FCFS length 0.0
# entrance rate: 13 service rate: 9
# average PQ length: 0.00725
# average R1 length: 0.0
# average R2 length 0.0
# average FCFS length 0.0
# entrance rate: 13 service rate: 9
# average PQ length: 0.60075
# average R1 length: 0.14
# average R2 length 0.01375
# average FCFS length 0.0
# entrance rate: 13 service rate: 9
# average PQ length: 1.7695
# average R1 length: 1.0885
# average R2 length 0.15225
# average FCFS length 0.0
# entrance rate: 13 service rate: 9
# average PQ length: 2.70675
# average R1 length: 1.00475
# average R2 length 0.26375
# average FCFS length 0.0
# entrance rate: 13 service rate: 9
# average PQ length: 2.8265
# average R1 length: 1.2715
# average R2 length 0.14525
# average FCFS length 0.0
# entrance rate: 13 service rate: 9
# average PQ length: 3.57475
# average R1 length: 34.8795
# average R2 length 0.0
# average FCFS length 0.0
# entrance rate: 13 service rate: 9
# average PQ length: 4.4465
# average R1 length: 5.81975
# average R2 length 0.8975
# average FCFS length 0.0
# entrance rate: 13 service rate: 9
# average PQ length: 5.70925
# average R1 length: 3.43125
# average R2 length 0.8215
# average FCFS length 0.0
# entrance rate: 13 service rate: 9
# average PQ length: 5.17975
# average R1 length: 2.00575
# average R2 length 0.3675
# average FCFS length 0.0
# entrance rate: 13 service rate: 9
# average PQ length: 9.0745
# average R1 length: 10.07825
# average R2 length 0.25675
# average FCFS length 0.0
# entrance rate: 13 service rate: 11
# average PQ length: 0.00675
# average R1 length: 0.0
# average R2 length 0.0
# average FCFS length 0.0
# entrance rate: 13 service rate: 11
# average PQ length: 0.73625
# average R1 length: 0.2225
# average R2 length 0.0495
# average FCFS length 0.0
# entrance rate: 13 service rate: 11
# average PQ length: 1.306
# average R1 length: 6.252
# average R2 length 0.0
# average FCFS length 0.0
# entrance rate: 13 service rate: 11
# average PQ length: 1.84175
# average R1 length: 1.04875
# average R2 length 0.941
# average FCFS length 0.0
# entrance rate: 13 service rate: 11
# average PQ length: 2.747
# average R1 length: 1.45325
# average R2 length 0.79625
# average FCFS length 0.0
# entrance rate: 13 service rate: 11
# average PQ length: 3.97125
# average R1 length: 3.2265
# average R2 length 0.837
# average FCFS length 0.0
# entrance rate: 13 service rate: 11
# average PQ length: 4.1355
# average R1 length: 1.1765
# average R2 length 0.27775
# average FCFS length 0.0
# entrance rate: 13 service rate: 11
# average PQ length: 6.18275
# average R1 length: 3.48025
# average R2 length 0.196
# average FCFS length 0.0
# entrance rate: 13 service rate: 11
# average PQ length: 5.74925
# average R1 length: 1.744
# average R2 length 0.9685
# average FCFS length 0.0
# entrance rate: 13 service rate: 11
# average PQ length: 9.49725
# average R1 length: 11.7835
# average R2 length 1.86125
# average FCFS length 0.0
# entrance rate: 13 service rate: 13
# average PQ length: 0.007
# average R1 length: 0.0
# average R2 length 0.0
# average FCFS length 0.0
# entrance rate: 13 service rate: 13
# average PQ length: 0.7585
# average R1 length: 1.997
# average R2 length 0.0
# average FCFS length 0.0
# entrance rate: 13 service rate: 13
# average PQ length: 1.2055
# average R1 length: 0.61025
# average R2 length 0.28125
# average FCFS length 0.0
# entrance rate: 13 service rate: 13
# average PQ length: 2.389
# average R1 length: 1.06625
# average R2 length 0.8945
# average FCFS length 0.0005
# entrance rate: 13 service rate: 13
# average PQ length: 2.3175
# average R1 length: 1.77275
# average R2 length 0.97175
# average FCFS length 0.00025
# entrance rate: 13 service rate: 13
# average PQ length: 3.70475
# average R1 length: 4.13375
# average R2 length 2.37
# average FCFS length 0.0
# entrance rate: 13 service rate: 13
# average PQ length: 3.522
# average R1 length: 2.527
# average R2 length 0.385
# average FCFS length 0.0
# entrance rate: 13 service rate: 13
# average PQ length: 6.08
# average R1 length: 4.61375
# average R2 length 0.19225
# average FCFS length 0.0
# entrance rate: 13 service rate: 13
# average PQ length: 5.8095
# average R1 length: 8.33875
# average R2 length 0.8715
# average FCFS length 0.0
# entrance rate: 13 service rate: 13
# average PQ length: 7.62625
# average R1 length: 3.642
# average R2 length 0.6365
# average FCFS length 0.0

# %% [markdown]
# ### average time spent in queue per job and per queue
# we can display the table for average waiting times in one of the queues:

# %%
from pandas import DataFrame
x = 20
y = 30
z = 200
jobs_result, queue_result = simulate(x, y, z)
print(jobs_result)
print('average time in PQ:', DataFrame.mean(jobs_result['PQ wt']))
print('average time in R1:', DataFrame.mean(jobs_result['R1 wt']))
print('average time in R2:', DataFrame.mean(jobs_result['R2 wt']))
print('average time in FCFS:', DataFrame.mean(jobs_result['FCFS wt']))
# Out:
#     id  priority  service time  created time  is done  PQ wt         R1 wt  \
# 0    1         2             1             0     True   90.0  9.300000e+01
# 1    2         3             3            10     True   80.0  9.710000e+01
# 2    3         2             3            28     True  362.0  3.800000e+00
# 3    4         3            42            42    False   18.0  7.800000e+01
# 4    5         3             2            55    False  125.0  1.921000e+02
# 5    6         3             1            82     True  128.0  2.202000e+02
# 6    7         3             4            83     True  157.0  2.463000e+02
# 7    8         3             2           100     True  260.0  3.668000e+02
# 8    9         3            22           124    False   26.0           NaN
# 9   10         2             3           126     True  714.0  2.136000e+02
# 10  11         3            21           189    False   81.0  2.653000e+02
# 11  12         3            45           190    False    NaN           NaN
# 12  13         3             3           203     True  817.0  3.900000e+02
# 13  14         3             4           229     True  791.0  3.930000e+02
# 14  15         3             3           298     True  212.0  4.400000e+00
# 15  16         1             4           316     True  104.0  3.410605e-13
# 16  17         3             6           332    False    NaN           NaN
# 17  18         3             2           343    False  197.0  9.400000e+00
# 18  19         3             4           357     True  633.0  3.670000e+02
# 19  20         3            24           378    False   42.0           NaN
# 20  21         3            17           384    False   66.0           NaN
# 21  22         3             2           401     True  139.0  2.340000e+01
# 22  23         3             1           419     True  361.0  1.374000e+02
# 23  24         2             1           433     True  467.0  2.816000e+02
# 24  25         3             1           446     True  304.0  1.114000e+02
# 25  26         3            10           447    False  243.0           NaN
# 26  27         3            17           462    False  108.0           NaN
# 27  28         3            38           474    False   66.0           NaN
# 28  29         1             5           531     True   99.0  1.300000e+01
# 29  30         3            12           540    False  360.0  2.906000e+02
#
#     R2 wt  FCFS wt
# 0    12.0      NaN
# 1     5.0      NaN
# 2     8.7      NaN
# 3     NaN      NaN
# 4     NaN      NaN
# 5     NaN      NaN
# 6     NaN      NaN
# 7    22.1      NaN
# 8     NaN      NaN
# 9     0.0      NaN
# 10    NaN      NaN
# 11    NaN      NaN
# 12    NaN      NaN
# 13  238.1      NaN
# 14    NaN      NaN
# 15    NaN      NaN
# 16    NaN      NaN
# 17    NaN      NaN
# 18  223.4      NaN
# 19    NaN      NaN
# 20    NaN      NaN
# 21    NaN      NaN
# 22    NaN      NaN
# 23  191.8      NaN
# 24    NaN      NaN
# 25    NaN      NaN
# 26    NaN      NaN
# 27    NaN      NaN
# 28    NaN      NaN
# 29    NaN      NaN
# average time in PQ: 251.78571428571428
# average time in R1: 172.60909090909277
# average time in R2: 87.63750000000044
# average time in FCFS: nan

# %% [markdown]
# Notice that due to a relatively short simulation time, most jobs won't reach the last queue.
# ### expired jobs rate
# We can also determine the portion of reneged jobs:

# %%
len(jobs_result[jobs_result['is done'] == False]) / len(jobs_result)
# Out:
# 0.43333333333333335

# %% [markdown]
# ### CPU utility
# since the 1-core is always working: $$\rho=1$$

# %% [markdown]
# ### how to improve average time spent in queues?
# The quantum time of queues must be greater or equal to the average of job service times. This is concluded from the fact that if we let the quantum time be less than the average service job, since our structure will transfer most of the jobs to the next queue, the system could get unstable. since all the jobs will be accumulated on the last queue and either the jobs will renege or they will have a really long waiting time.
